# %% [markdown]
# # Compute global time mean on the MOM6 surface data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import m6plot
from mom6_diag import MOM6grid, mean_latlon_plot

# %%
# create a class and add necessary arguments
# this class replaces argparse and should be used in Notebooks
class args:
    pass

args.case_name = 'g.c2b6.GNYF.T62_t061.kpp.002'
run_path = '/project/oce/mom6/test_cases/'+args.case_name+'/run/'
args.surface_file = run_path + 'sfc_daily_*.nc'
args.forcing_file = run_path + 'forcing_*.nc'
args.year_start = 2
args.year_end = 7
args.savefigs = False

# load MOM6 horizontal grid
grd = MOM6grid(run_path+'ocean_geometry.nc')
# Out:
# MOM6 grid successfully loaded...

# %%
mean_latlon_plot(args,grd,['SSH','SSS','SST','MLD_003','SSU','SSV','hfds','PRCmE'])
# Out:
# About to plot surface time-average for variable SSH...
# /home/gmarques/miniconda2/lib/python2.7/site-packages/dask/array/numpy_compat.py:48: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# About to plot surface time-average for variable SSS...
# About to plot surface time-average for variable SST...
# About to plot surface time-average for variable MLD_003...
# About to plot surface time-average for variable SSU...
# About to plot surface time-average for variable SSV...
# About to plot surface time-average for variable hfds...
# About to plot surface time-average for variable PRCmE...
